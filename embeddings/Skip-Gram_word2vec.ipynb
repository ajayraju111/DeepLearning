# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils
# Out:
# C:\Users\Rishabh Sharma\Anaconda3\envs\tensorflow_gpu\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:37, 838kB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None] ,name="inputs")
    labels = tf.placeholder(tf.int32, shape=[None,None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding,inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w,softmax_b,labels,embed,n_sampled,n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From C:\Users\Rishabh Sharma\Anaconda3\envs\tensorflow_gpu\lib\site-packages\tensorflow\python\ops\nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-16-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6522 0.2336 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6067 0.2044 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5189 0.1980 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5830 0.2010 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5514 0.1918 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5227 0.1908 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5402 0.1909 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5441 0.1923 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4704 0.1917 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4079 0.1920 sec/batch
# Nearest to to: flathead, absolute, linear, lps, luthiers, rousing, kneaded, totschlag,
# Nearest to one: kilroy, congo, svalbard, gullit, butane, shouldn, afterglow, has,
# Nearest to most: cassandra, raisin, rhoda, convincing, consecrate, molesworth, kinnear, socialize,
# Nearest to more: signatory, asg, schama, fenway, fundamentalist, simonds, herodotus, muskets,
# Nearest to called: laurens, calls, spins, limburg, knox, stances, reassurance, friedrich,
# Nearest to history: corpses, slaves, echoed, hatha, inductively, scalemajor, pursuit, vegan,
# Nearest to been: salamanca, cousins, facie, cooperatively, deerfield, lingvo, biathletes, photoshop,
# Nearest to as: stuck, boss, proteg, vukovar, multiplicative, discoid, hazard, banknote,
# Nearest to square: biomedical, buffon, blacklist, tate, aluma, te, hallam, joule,
# Nearest to operating: boarded, fp, frontispiece, cataclysm, unduly, heathcote, hyperbole, juvenal,
# Nearest to question: petherbridge, vines, arminians, itil, unsteady, rupee, passively, gorda,
# Nearest to universe: burghs, tab, tuc, antimony, flammarion, afrikaans, nanos, two,
# Nearest to cost: hartree, spacecrafts, penny, reabsorption, tab, synth, mcluhan, guaranteed,
# Nearest to applied: experts, cracked, worth, razzie, sunil, isolde, ech, emilio,
# Nearest to engineering: spawn, seebeck, ailuropoda, smelt, sued, kfor, certify, muskegon,
# Nearest to joseph: penitent, complicit, strings, breathes, bannon, mccaffrey, chechens, fizeau,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5002 0.1957 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3841 0.1918 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3154 0.1921 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2449 0.1920 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1966 0.1918 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1550 0.1920 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0969 0.1932 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0582 0.1933 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9731 0.1918 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9743 0.1933 sec/batch
# Nearest to to: absolute, linear, flathead, supply, household, lps, north, operation,
# Nearest to one: congo, kilroy, org, economical, modern, shouldn, ministries, having,
# Nearest to most: cassandra, convincing, computers, emphasis, intolerant, raisin, kinnear, rhoda,
# Nearest to more: signatory, fundamentalist, metal, who, asg, supplied, assistive, otherwise,
# Nearest to called: calls, spins, friedrich, stances, females, laurens, office, not,
# Nearest to history: corpses, echoed, social, slaves, pursuit, commanded, accomplishment, per,
# Nearest to been: cousins, average, considers, star, operating, facie, manage, cooperatively,
# Nearest to as: stuck, boss, proteg, solved, hazard, develop, percent, multiplicative,
# Nearest to square: biomedical, blacklist, mile, joule, te, buffon, encyclopedists, hallam,
# Nearest to operating: boarded, been, solar, juvenal, limited, fp, throwing, frontispiece,
# Nearest to question: vines, making, dedicated, arose, transit, american, either, petherbridge,
# Nearest to universe: tab, twenty, burghs, governments, tuc, branches, manchester, handled,
# Nearest to cost: penny, guaranteed, activity, tab, hartree, continental, reabsorption, correctness,
# Nearest to applied: experts, worth, usage, putting, isn, appearances, cracked, galleries,
# Nearest to engineering: sued, spawn, underway, coarse, seebeck, engineers, coin, disprove,
# Nearest to joseph: strings, penitent, bannon, mccaffrey, breathes, complicit, solution, chechens,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9291 0.1940 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9437 0.1921 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8758 0.1923 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8734 0.1923 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8205 0.1915 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8226 0.1921 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8078 0.1928 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7964 0.1933 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7695 0.1926 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7640 0.1943 sec/batch
# Nearest to to: linear, absolute, flathead, lps, inaccurate, luthiers, household, supply,
# Nearest to one: nine, congo, christina, kilroy, economical, lauren, four, uefa,
# Nearest to most: cassandra, convincing, supporter, rhoda, hardly, subdivisions, consecrate, computers,
# Nearest to more: signatory, metal, supplied, glass, fundamentalist, fenway, labeled, who,
# Nearest to called: calls, spins, laurens, stances, knox, friedrich, climatic, limburg,
# Nearest to history: corpses, slaves, echoed, accomplishment, scalemajor, social, commanded, pursuit,
# Nearest to been: cousins, star, facie, operating, deerfield, cooperatively, developments, photoshop,
# Nearest to as: stuck, boss, multiplicative, letter, initially, develop, researched, vukovar,
# Nearest to square: biomedical, mile, blacklist, joule, te, buffon, frustrations, encyclopedists,
# Nearest to operating: boarded, been, fp, solar, hyperbole, blair, anthology, input,
# Nearest to question: vines, petherbridge, miguel, unsteady, dedicated, monarch, making, uppercase,
# Nearest to universe: burghs, tab, twenty, flammarion, tuc, antimony, manchester, wasteland,
# Nearest to cost: penny, tab, hartree, activity, guaranteed, abundant, continental, correctness,
# Nearest to applied: experts, worth, putting, cracked, appearances, temperate, immigration, electronic,
# Nearest to engineering: seebeck, engineers, spawn, coarse, intuitive, underway, coin, tukey,
# Nearest to joseph: penitent, strings, breathes, bannon, mccaffrey, neanderthals, complicit, chechens,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7769 0.1976 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7579 0.1945 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7431 0.1936 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6940 0.1930 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7380 0.1944 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7004 0.1944 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6858 0.2048 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7242 0.1932 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6960 0.2040 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6860 0.1942 sec/batch
# Nearest to to: absolute, flathead, linear, lps, rousing, supply, dialectal, luthiers,
# Nearest to one: nine, four, christina, congo, poet, kilroy, lauren, kennedys,
# Nearest to most: cassandra, raisin, convincing, cagney, rhoda, molesworth, consecrate, subdivisions,
# Nearest to more: signatory, metal, supplied, glass, fenway, rhythm, fundamentalist, enforcement,
# Nearest to called: calls, laurens, spins, knox, stances, profess, limburg, climatic,
# Nearest to history: corpses, slaves, exam, echoed, accomplishment, scalemajor, voyaging, social,
# Nearest to been: cousins, deerfield, facie, star, photoshop, salamanca, chairmen, cooperatively,
# Nearest to as: stuck, vukovar, boss, initially, letter, develop, banknote, chambre,
# Nearest to square: biomedical, tate, mile, joule, blacklist, te, hallam, frustrations,
# Nearest to operating: boarded, fp, hyperbole, been, solar, twickenham, input, juvenal,
# Nearest to question: petherbridge, vines, lothair, unsteady, uppercase, itil, miguel, arminians,
# Nearest to universe: burghs, antimony, tab, wasteland, tuc, flammarion, fuelling, excitatory,
# Nearest to cost: recognising, tab, spacecrafts, abundant, hartree, synth, penny, reabsorption,
# Nearest to applied: experts, temperate, cracked, worth, immigration, isolde, downloads, putting,
# Nearest to engineering: seebeck, engineers, tukey, certify, coarse, spawn, alloys, intuitive,
# Nearest to joseph: penitent, breathes, samuel, bannon, strings, mccaffrey, complicit, bioko,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6816 0.1965 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6651 0.1935 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6174 0.1932 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6281 0.1950 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6316 0.1940 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6109 0.1940 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6130 0.1438 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5331 0.1938 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5364 0.1941 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5106 0.1944 sec/batch
# Nearest to to: absolute, flathead, lps, linear, dialectal, carefully, rousing, supply,
# Nearest to one: nine, four, poet, christina, six, congo, french, lauren,
# Nearest to most: cassandra, raisin, molesworth, kinnear, francoist, cagney, convincing, numerals,
# Nearest to more: signatory, metal, glass, assistive, rhythm, supplied, decreases, indicative,
# Nearest to called: calls, spins, knox, laurens, profess, stances, reassurance, dehydrogenase,
# Nearest to history: corpses, slaves, exam, voyaging, echoed, scalemajor, social, blish,
# Nearest to been: cousins, deerfield, photoshop, star, facie, chairmen, recognizable, attaches,
# Nearest to as: stuck, banknote, initially, develop, modules, proteg, discoid, vukovar,
# Nearest to square: biomedical, mile, tate, joule, blacklist, te, ntr, buffon,
# Nearest to operating: boarded, input, fp, hyperbole, solar, twickenham, been, protective,
# Nearest to question: lothair, petherbridge, vines, itil, unsteady, arminians, uppercase, bodybuilder,
# Nearest to universe: antimony, excitatory, tuc, burghs, wasteland, tab, fuelling, flammarion,
# Nearest to cost: recognising, tab, spacecrafts, hartree, abundant, synth, cadres, penny,
# Nearest to applied: experts, temperate, cracked, isolde, mild, sps, putting, advanced,
# Nearest to engineering: alloys, tukey, engineers, intuitive, seebeck, amino, certify, applications,
# Nearest to joseph: penitent, samuel, breathes, bannon, bioko, mccaffrey, acheson, harvey,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4805 0.1951 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5107 0.1942 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4778 0.1952 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5285 0.1937 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4842 0.1928 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4829 0.1952 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4776 0.1964 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4325 0.1932 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4315 0.1952 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4069 0.1944 sec/batch
# Nearest to to: absolute, flathead, lps, linear, supply, carefully, dialectal, kneaded,
# Nearest to one: four, nine, christina, uefa, lauren, congo, svalbard, six,
# Nearest to most: raisin, molesworth, cassandra, flocks, austral, numerals, francoist, kinnear,
# Nearest to more: metal, signatory, glass, asg, decreases, assistive, rhythm, supplied,
# Nearest to called: calls, spins, laurens, dehydrogenase, climatic, profess, separator, knox,
# Nearest to history: corpses, slaves, exam, voyaging, east, echoed, scalemajor, insecure,
# Nearest to been: deerfield, attaches, cousins, chairmen, facie, conspiratorial, photoshop, recognizable,
# Nearest to as: stuck, proteg, banknote, modules, develop, initially, widens, vukovar,
# Nearest to square: mile, biomedical, tate, te, ntr, joule, hallam, fichte,
# Nearest to operating: boarded, input, fp, mhz, hyperbole, unix, programming, solar,
# Nearest to question: lothair, petherbridge, vines, itil, unsteady, steno, bodybuilder, uppercase,
# Nearest to universe: excitatory, tuc, antimony, fuelling, burghs, wasteland, tab, pancreatic,
# Nearest to cost: recognising, tab, hartree, correctness, spacecrafts, abundant, penny, synth,
# Nearest to applied: experts, commonsense, temperate, isolde, advanced, mutagenesis, putting, sps,
# Nearest to engineering: engineers, tukey, intermediates, amino, alloys, seebeck, artifice, refilled,
# Nearest to joseph: penitent, samuel, bioko, acheson, mccaffrey, breathes, arar, metallized,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4200 0.1952 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4245 0.1933 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4500 0.1935 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4231 0.1933 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4197 0.1937 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4399 0.1941 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3842 0.1941 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3875 0.1958 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4148 0.1946 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.4032 0.1930 sec/batch
# Nearest to to: flathead, absolute, lps, dialectal, rousing, linear, supply, inaccurate,
# Nearest to one: four, nine, six, svalbard, five, scientist, lauren, congo,
# Nearest to most: raisin, cassandra, francoist, molesworth, spares, numerals, consecrate, flocks,
# Nearest to more: signatory, assistive, metal, ciders, enforcement, asg, rhythm, pleasing,
# Nearest to called: spins, calls, stances, knox, laurens, profess, separator, dehydrogenase,
# Nearest to history: corpses, exam, slaves, voyaging, echoed, blish, east, insecure,
# Nearest to been: cousins, conspiratorial, facie, deerfield, considers, wounds, recognizable, cooperatively,
# Nearest to as: stuck, initially, proteg, banknote, thrush, widens, oeuvre, vukovar,
# Nearest to square: mile, biomedical, tate, joule, ntr, affonso, te, endorsing,
# Nearest to operating: boarded, input, fp, unix, hyperbole, microsoft, mhz, pc,
# Nearest to question: lothair, petherbridge, vines, itil, asks, varma, tte, uppercase,
# Nearest to universe: excitatory, fuelling, wasteland, antimony, tuc, burghs, pancreatic, transgressing,
# Nearest to cost: recognising, tab, correctness, spacecrafts, hartree, penny, facilities, abundant,
# Nearest to applied: experts, commonsense, isolde, mutagenesis, putting, sps, temperate, mild,
# Nearest to engineering: engineers, tukey, intermediates, artifice, amino, seebeck, alloys, jockeys,
# Nearest to joseph: penitent, samuel, bioko, mccaffrey, gorham, acheson, arar, rob,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3808 0.1950 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3770 0.1948 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3697 0.1941 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3685 0.1939 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3861 0.1953 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3590 0.1955 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4013 0.1941 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3844 0.1935 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3437 0.1923 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3459 0.1945 sec/batch
# Nearest to to: flathead, absolute, lps, dialectal, linear, rousing, queueing, gra,
# Nearest to one: four, nine, six, five, three, svalbard, congo, scientist,
# Nearest to most: raisin, francoist, molesworth, numerals, austral, consecrate, tat, sinning,
# Nearest to more: assistive, signatory, metal, ciders, pleasing, asg, broadsheet, enforcement,
# Nearest to called: calls, spins, profess, laurens, knox, gripped, reassurance, limburg,
# Nearest to history: corpses, slaves, east, exam, voyaging, blish, social, echoed,
# Nearest to been: cousins, conspiratorial, considers, developments, chairmen, deerfield, facie, attaches,
# Nearest to as: widens, stuck, initially, typify, thrush, proteg, banknote, witnessing,
# Nearest to square: mile, biomedical, tate, joule, ntr, te, endorsing, affonso,
# Nearest to operating: boarded, input, fp, microsoft, unix, mhz, pc, virtual,
# Nearest to question: lothair, petherbridge, vines, itil, uppercase, passively, tte, rightfully,
# Nearest to universe: excitatory, fuelling, wasteland, antimony, pancreatic, dancers, burghs, transgressing,
# Nearest to cost: recognising, facilities, spacecrafts, correctness, tab, investment, penny, hartree,
# Nearest to applied: experts, commonsense, sps, mutagenesis, electronic, reconstructionist, capitalization, guimar,
# Nearest to engineering: engineers, tukey, intermediates, artifice, amino, seebeck, bio, alloys,
# Nearest to joseph: penitent, samuel, bioko, mccaffrey, acheson, complicit, wolpert, ebenezer,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3525 0.1969 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2838 0.1955 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3699 0.1956 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3803 0.1954 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4052 0.1938 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2942 0.1942 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3470 0.1945 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3487 0.1936 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2076 0.1953 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3218 0.1937 sec/batch
# Nearest to to: flathead, absolute, lps, rousing, carefully, triggers, dialectal, aimed,
# Nearest to one: four, nine, six, five, three, eight, scientist, pedro,
# Nearest to most: molesworth, francoist, raisin, numerals, tat, austral, numerous, consecrate,
# Nearest to more: assistive, ciders, signatory, metal, photon, pleasing, broadsheet, asg,
# Nearest to called: calls, profess, laurens, dehydrogenase, spins, knox, persona, friedrich,
# Nearest to history: corpses, exam, east, blish, voyaging, slaves, echoed, menial,
# Nearest to been: conspiratorial, cousins, considers, developments, deerfield, modernise, facie, numbering,
# Nearest to as: stuck, thrush, rowley, banknote, oeuvre, initially, ate, widens,
# Nearest to square: mile, tate, biomedical, joule, ntr, te, affonso, louisiana,
# Nearest to operating: boarded, fp, unix, microsoft, input, mhz, virtual, pc,
# Nearest to question: petherbridge, lothair, rightfully, vines, passively, tte, unsteady, uppercase,
# Nearest to universe: excitatory, fuelling, transgressing, invoking, pancreatic, wasteland, itineraries, witt,
# Nearest to cost: recognising, correctness, spacecrafts, tab, facilities, investment, worth, hartree,
# Nearest to applied: experts, commonsense, sps, mutagenesis, usage, electronic, advanced, capitalization,
# Nearest to engineering: engineers, tukey, intermediates, amino, alloys, seebeck, artifice, refilled,
# Nearest to joseph: penitent, samuel, bioko, wolpert, acheson, complicit, ebenezer, clement,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3018 0.1959 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3173 0.1947 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3292 0.0934 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2401 0.1947 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2050 0.1935 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1993 0.1937 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2263 0.1922 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2057 0.1921 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2441 0.1923 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2175 0.1932 sec/batch
# Nearest to to: flathead, lps, triggers, absolute, queueing, aimed, carefully, in,
# Nearest to one: four, nine, six, five, three, eight, svalbard, scientist,
# Nearest to most: francoist, molesworth, raisin, numerals, austral, tat, rood, sinning,
# Nearest to more: assistive, ciders, pleasing, signatory, metal, photon, credit, broadsheet,
# Nearest to called: dehydrogenase, separator, profess, spins, calls, flattening, derivable, laurens,
# Nearest to history: east, corpses, exam, voyaging, blish, midtown, hatha, interceptor,
# Nearest to been: conspiratorial, deerfield, attaches, cousins, considers, chairmen, developments, star,
# Nearest to as: hazard, widens, thrush, banknote, stuck, vukovar, excerpted, oeuvre,
# Nearest to square: mile, tate, biomedical, ntr, joule, affonso, louisiana, ancona,
# Nearest to operating: boarded, fp, unix, microsoft, virtual, input, mhz, limited,
# Nearest to question: lothair, petherbridge, rightfully, passively, asks, tte, affirms, uppercase,
# Nearest to universe: excitatory, transgressing, fuelling, invoking, cubicle, pancreatic, witt, subsonic,
# Nearest to cost: facilities, spacecrafts, worth, correctness, recognising, investment, tab, penny,
# Nearest to applied: experts, commonsense, mutagenesis, temperate, reconstructionist, conjectural, usage, cryptanalyst,
# Nearest to engineering: engineers, tukey, intermediates, alloys, amino, bio, refilled, artifice,
# Nearest to joseph: penitent, samuel, acheson, clement, mccaffrey, ebenezer, bioko, wolpert,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2614 0.1953 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2253 0.1953 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2424 0.1959 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1274 0.1936 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1701 0.1932 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1780 0.1930 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1915 0.1918 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1770 0.1924 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2080 0.1926 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1853 0.1921 sec/batch
# Nearest to to: aimed, flathead, absolute, otherwise, lps, triggers, able, phlogiston,
# Nearest to one: four, nine, six, five, three, eight, marr, hdi,
# Nearest to most: francoist, numerals, tat, molesworth, raisin, denominators, cove, philby,
# Nearest to more: assistive, metal, pleasing, ciders, fabricate, credit, photon, indicative,
# Nearest to called: dehydrogenase, separator, spins, flattening, calls, superclasses, profess, alveoli,
# Nearest to history: corpses, voyaging, exam, hatha, east, blish, midtown, interceptor,
# Nearest to been: conspiratorial, developments, attaches, biathletes, cousins, numbering, considers, universalist,
# Nearest to as: thrush, widens, hazard, oeuvre, detect, banknote, rowley, stuck,
# Nearest to square: mile, tate, louisiana, ntr, affonso, biomedical, parks, te,
# Nearest to operating: boarded, fp, unix, microsoft, virtual, input, vetted, mhz,
# Nearest to question: lothair, petherbridge, passively, rightfully, affirms, arminians, tte, worshippers,
# Nearest to universe: excitatory, transgressing, invoking, fuelling, bang, cubicle, quasars, witt,
# Nearest to cost: recognising, correctness, spacecrafts, worth, investment, facilities, tab, penny,
# Nearest to applied: experts, commonsense, herpes, mutagenesis, electronic, usage, cryptanalyst, galleries,
# Nearest to engineering: engineers, tukey, bio, intermediates, alloys, research, artifice, smelt,
# Nearest to joseph: penitent, samuel, ebenezer, clement, mccaffrey, complicit, wolpert, sternberg,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1818 0.1938 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2042 0.1925 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1836 0.1929 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1283 0.1923 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1934 0.1921 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2004 0.1929 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2271 0.1931 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1722 0.1920 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1560 0.1960 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1926 0.1953 sec/batch
# Nearest to to: flathead, absolute, aimed, linear, otherwise, lps, queueing, correctness,
# Nearest to one: four, nine, six, three, five, eight, zero, two,
# Nearest to most: francoist, numerals, tat, molesworth, cove, philby, numerous, sinning,
# Nearest to more: assistive, pleasing, metal, credit, ciders, fabricate, calibrated, rhythm,
# Nearest to called: dehydrogenase, profess, spins, calls, flattening, persona, alveoli, superclasses,
# Nearest to history: voyaging, hatha, corpses, exam, blish, east, org, cpes,
# Nearest to been: conspiratorial, considers, developments, numbering, revoke, star, lingvo, cousins,
# Nearest to as: hazard, oeuvre, rowley, thrush, detect, anthracite, banknote, atb,
# Nearest to square: mile, tate, joule, ntr, biomedical, affonso, louisiana, parks,
# Nearest to operating: boarded, fp, unix, microsoft, virtual, vetted, scsi, limited,
# Nearest to question: petherbridge, lothair, rightfully, passively, affirms, colds, arminians, worshippers,
# Nearest to universe: excitatory, transgressing, bang, invoking, fuelling, cubicle, quasars, herschel,
# Nearest to cost: worth, recognising, spacecrafts, facilities, correctness, tab, investment, penny,
# Nearest to applied: experts, commonsense, electronic, mutagenesis, waddingtons, cryptanalyst, usage, herpes,
# Nearest to engineering: engineers, tukey, bio, intermediates, research, organisation, artifice, canberra,
# Nearest to joseph: penitent, samuel, ebenezer, mccaffrey, clement, complicit, acheson, wolpert,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1957 0.1976 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1799 0.1955 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1951 0.1933 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1832 0.1931 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1630 0.1940 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1443 0.1951 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1631 0.1946 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1211 0.1936 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1858 0.1953 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2020 0.1924 sec/batch
# Nearest to to: aimed, flathead, golconda, absolute, in, rousing, able, otherwise,
# Nearest to one: four, nine, five, three, six, eight, two, zero,
# Nearest to most: francoist, tat, numerals, numerous, cove, molesworth, shari, genres,
# Nearest to more: assistive, pleasing, fabricate, rhythm, ciders, metal, credit, asg,
# Nearest to called: profess, persona, laurens, flattening, knowbot, dehydrogenase, calls, friedrich,
# Nearest to history: blish, hatha, east, org, voyaging, corpses, cpes, mazar,
# Nearest to been: conspiratorial, developments, considers, chairmen, revoke, cousins, universalist, admetus,
# Nearest to as: rowley, oeuvre, banknote, anthracite, asser, thrush, chambre, priest,
# Nearest to square: mile, tate, joule, parks, affonso, ntr, louisiana, biomedical,
# Nearest to operating: boarded, fp, unix, vetted, mauritians, grille, hubs, microsoft,
# Nearest to question: petherbridge, rightfully, arminians, passively, lothair, worshippers, subservient, itil,
# Nearest to universe: excitatory, transgressing, bang, invoking, fuelling, cubicle, herschel, brane,
# Nearest to cost: recognising, worth, spacecrafts, correctness, facilities, investment, tab, mcluhan,
# Nearest to applied: experts, commonsense, waddingtons, electronic, galleries, forefront, mutagenesis, cryptanalyst,
# Nearest to engineering: engineers, bio, tukey, research, intermediates, canberra, organisation, architecture,
# Nearest to joseph: penitent, samuel, ebenezer, complicit, wolpert, acheson, clement, mccaffrey,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2331 0.1972 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1170 0.1946 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1359 0.1936 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1743 0.1934 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0461 0.1938 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1600 0.1931 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1521 0.1941 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1363 0.1930 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1751 0.0429 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1005 0.1929 sec/batch
# Nearest to to: aimed, queueing, linear, in, able, absolute, otherwise, rousing,
# Nearest to one: four, nine, five, three, six, eight, two, zero,
# Nearest to most: francoist, numerals, tat, molesworth, numerous, genres, cove, retail,
# Nearest to more: assistive, pleasing, fabricate, metal, ciders, calibrated, rhythm, greater,
# Nearest to called: flattening, dehydrogenase, persona, profess, simple, knowbot, separator, calls,
# Nearest to history: blish, east, voyaging, hatha, org, cpes, corpses, exam,
# Nearest to been: biathletes, star, attaches, developments, conspiratorial, settings, admetus, deerfield,
# Nearest to as: oeuvre, banknote, thrush, anthracite, technologists, rowley, asser, detect,
# Nearest to square: mile, tate, affonso, joule, ntr, parks, serendipity, te,
# Nearest to operating: boarded, fp, unix, vetted, microsoft, virtual, twickenham, hubs,
# Nearest to question: petherbridge, rightfully, passively, arminians, lothair, affirms, subservient, asks,
# Nearest to universe: excitatory, transgressing, invoking, cubicle, fuelling, bang, brane, herschel,
# Nearest to cost: recognising, worth, spacecrafts, correctness, tab, mcluhan, penny, facilities,
# Nearest to applied: experts, commonsense, electronic, waddingtons, advanced, galleries, mutagenesis, artis,
# Nearest to engineering: engineers, bio, research, tukey, intermediates, canberra, alloys, smelt,
# Nearest to joseph: penitent, samuel, ebenezer, wolpert, complicit, sternberg, acheson, clement,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0814 0.1947 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0617 0.1938 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0807 0.1967 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0542 0.1941 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0721 0.1948 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0737 0.1932 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1182 0.1947 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0981 0.1930 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1295 0.1930 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0223 0.1935 sec/batch
# Nearest to to: aimed, in, able, absolute, triggers, linear, otherwise, a,
# Nearest to one: four, nine, five, three, six, eight, two, zero,
# Nearest to most: francoist, numerals, tat, molesworth, numerous, genres, rood, popular,
# Nearest to more: assistive, metal, pleasing, fabricate, ciders, calibrated, rhythm, photon,
# Nearest to called: profess, flattening, dehydrogenase, alveoli, persona, simple, combinations, superclasses,
# Nearest to history: east, blish, hatha, voyaging, external, cpes, org, midtown,
# Nearest to been: biathletes, conspiratorial, attaches, admetus, star, deerfield, developments, settings,
# Nearest to as: oeuvre, asser, banknote, microscopic, cac, thrush, anthracite, rowley,
# Nearest to square: mile, tate, affonso, joule, serendipity, ntr, parks, endorsing,
# Nearest to operating: boarded, fp, unix, virtual, vetted, core, hubs, onboard,
# Nearest to question: petherbridge, arminians, passively, rightfully, affirms, subservient, itil, lothair,
# Nearest to universe: excitatory, bang, brane, invoking, herschel, transgressing, quasars, cosmic,
# Nearest to cost: recognising, worth, spacecrafts, tab, penny, correctness, mcluhan, facilities,
# Nearest to applied: experts, commonsense, waddingtons, advanced, electronic, galleries, mutagenesis, artis,
# Nearest to engineering: engineers, bio, research, canberra, tukey, intermediates, chemistry, smelt,
# Nearest to joseph: penitent, samuel, ebenezer, acheson, complicit, mccaffrey, sternberg, antoinette,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9933 0.1949 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0359 0.1936 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0450 0.1918 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0563 0.1919 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0775 0.1930 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0805 0.1956 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0732 0.1956 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1189 0.1924 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0464 0.1949 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0589 0.1943 sec/batch
# Nearest to to: aimed, in, absolute, linear, otherwise, specifying, queueing, able,
# Nearest to one: four, nine, five, three, six, eight, zero, two,
# Nearest to most: francoist, tat, numerals, genres, biola, numerous, rood, philby,
# Nearest to more: assistive, pleasing, metal, fabricate, ciders, calibrated, rhythm, sundanese,
# Nearest to called: flattening, persona, alveoli, dehydrogenase, profess, simple, superclasses, derivable,
# Nearest to history: cpes, blish, hatha, voyaging, cnet, external, org, freeserve,
# Nearest to been: biathletes, star, conspiratorial, settings, admetus, developments, cousins, attaches,
# Nearest to as: oeuvre, microscopic, yaoi, sensing, asser, thrush, detect, banknote,
# Nearest to square: mile, tate, serendipity, joule, affonso, ntr, ebenezer, laszlo,
# Nearest to operating: boarded, fp, unix, vetted, hubs, virtual, onboard, core,
# Nearest to question: petherbridge, arminians, passively, affirms, rightfully, lothair, colds, itil,
# Nearest to universe: excitatory, bang, brane, transgressing, quasars, invoking, herschel, galaxies,
# Nearest to cost: worth, recognising, spacecrafts, tab, correctness, penny, mcluhan, investment,
# Nearest to applied: experts, commonsense, waddingtons, electronic, forefront, engineering, classroom, galleries,
# Nearest to engineering: engineers, bio, research, canberra, tukey, doctorate, intermediates, smelt,
# Nearest to joseph: penitent, samuel, ebenezer, acheson, sternberg, wolpert, complicit, mccaffrey,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0486 0.1960 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0763 0.1932 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.1089 0.1926 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0521 0.1923 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0614 0.1932 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0673 0.1940 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0697 0.1956 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0578 0.1960 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0864 0.1934 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0806 0.1928 sec/batch
# Nearest to to: aimed, in, absolute, golconda, able, otherwise, linear, embodies,
# Nearest to one: four, nine, five, three, six, eight, zero, two,
# Nearest to most: francoist, tat, numerous, molesworth, numerals, genres, biola, rood,
# Nearest to more: assistive, fabricate, metal, pleasing, greater, ciders, rhythm, calibrated,
# Nearest to called: profess, flattening, persona, alveoli, simple, dehydrogenase, konkan, traitors,
# Nearest to history: east, external, afridi, tertullian, armenia, voyaging, hatha, blish,
# Nearest to been: star, biathletes, developments, admetus, conspiratorial, universalist, settings, discovered,
# Nearest to as: oeuvre, asser, rowley, yaoi, atb, priest, conciliar, banknote,
# Nearest to square: mile, tate, serendipity, affonso, laszlo, ntr, ebenezer, joule,
# Nearest to operating: boarded, fp, unix, vetted, hubs, paveway, virtual, onboard,
# Nearest to question: petherbridge, arminians, subservient, colds, itil, rightfully, affirms, passively,
# Nearest to universe: excitatory, bang, brane, herschel, galaxies, quasars, invoking, transgressing,
# Nearest to cost: worth, correctness, recognising, spacecrafts, tab, penny, mcluhan, objector,
# Nearest to applied: experts, commonsense, waddingtons, forefront, electronic, galleries, advanced, classroom,
# Nearest to engineering: engineers, bio, research, canberra, intermediates, tukey, doctorate, smelt,
# Nearest to joseph: penitent, samuel, acheson, wolpert, ebenezer, complicit, mccaffrey, sternberg,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0615 0.1947 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0417 0.1925 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0203 0.1921 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0828 0.1935 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0904 0.1941 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0978 0.1928 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1107 0.1928 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0569 0.1926 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0454 0.1921 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0568 0.1921 sec/batch
# Nearest to to: aimed, in, absolute, linear, otherwise, queueing, a, apocalypticism,
# Nearest to one: four, nine, five, three, six, eight, two, zero,
# Nearest to most: francoist, numerals, biola, genres, numerous, tat, rood, molesworth,
# Nearest to more: assistive, fabricate, metal, pleasing, greater, ciders, photon, rhythm,
# Nearest to called: profess, flattening, konkan, slovenia, simple, persona, aristobulus, traitors,
# Nearest to history: cpes, external, cnet, voyaging, blish, hatha, afridi, east,
# Nearest to been: star, developments, settings, admetus, biathletes, conspiratorial, guarantors, considers,
# Nearest to as: oeuvre, rowley, asser, yaoi, name, atb, conciliar, technologists,
# Nearest to square: mile, tate, serendipity, laszlo, affonso, joule, kali, parks,
# Nearest to operating: boarded, fp, unix, vetted, hubs, paveway, virtual, local,
# Nearest to question: petherbridge, arminians, itil, colds, rightfully, passively, subservient, affirms,
# Nearest to universe: excitatory, brane, bang, herschel, quasars, transgressing, galaxies, invoking,
# Nearest to cost: worth, recognising, spacecrafts, correctness, tab, mcluhan, penny, objector,
# Nearest to applied: experts, commonsense, waddingtons, advanced, forefront, galleries, electronic, classroom,
# Nearest to engineering: engineers, bio, canberra, research, doctorate, tukey, smelt, rtp,
# Nearest to joseph: penitent, samuel, acheson, complicit, solution, wolpert, sternberg, ebenezer,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9799 0.1941 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0421 0.1928 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0633 0.1927 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0618 0.1932 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0820 0.1929 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0519 0.1859 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0241 0.1943 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9801 0.1930 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9915 0.1934 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9866 0.1931 sec/batch
# Nearest to to: aimed, in, a, absolute, golconda, embodies, otherwise, destabilizing,
# Nearest to one: four, nine, five, six, three, eight, two, zero,
# Nearest to most: francoist, numerals, genres, biola, numerous, molesworth, tat, popular,
# Nearest to more: assistive, fabricate, greater, photon, pleasing, metal, considerably, sundanese,
# Nearest to called: profess, dehydrogenase, flattening, persona, alveoli, simple, traitors, superclasses,
# Nearest to history: voyaging, cpes, hatha, blish, east, cnet, histories, midtown,
# Nearest to been: star, conspiratorial, biathletes, discovered, admetus, developments, settings, cousins,
# Nearest to as: name, oeuvre, microscopic, rowley, technologists, levantine, cac, yaoi,
# Nearest to square: mile, tate, serendipity, laszlo, joule, kali, wall, affonso,
# Nearest to operating: unix, boarded, fp, paveway, hubs, vetted, microsoft, virtual,
# Nearest to question: petherbridge, arminians, subservient, colds, itil, passively, affirms, asks,
# Nearest to universe: excitatory, brane, bang, transgressing, quasars, herschel, invoking, galaxies,
# Nearest to cost: worth, spacecrafts, correctness, recognising, iie, objector, mcluhan, penny,
# Nearest to applied: experts, commonsense, waddingtons, galleries, advanced, classroom, forefront, electronic,
# Nearest to engineering: engineers, canberra, bio, doctorate, research, smelt, intermediates, tukey,
# Nearest to joseph: penitent, samuel, acheson, wolpert, broughton, complicit, ebenezer, sternberg,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9463 0.1951 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9329 0.1926 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0303 0.1926 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0220 0.1928 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0337 0.1933 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9900 0.1937 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9053 0.1931 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9719 0.1939 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9250 0.1935 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.0125 0.1934 sec/batch
# Nearest to to: in, aimed, a, otherwise, prominence, absolute, embodies, queueing,
# Nearest to one: four, nine, five, three, six, two, eight, zero,
# Nearest to most: francoist, genres, numerals, biola, minority, numerous, tat, molesworth,
# Nearest to more: assistive, fabricate, greater, photon, ciders, pleasing, considerably, metal,
# Nearest to called: alveoli, profess, dehydrogenase, flattening, persona, simple, traitors, superclasses,
# Nearest to history: cpes, voyaging, hatha, world, cnet, external, blish, east,
# Nearest to been: biathletes, discovered, have, developments, star, settings, conspiratorial, admetus,
# Nearest to as: microscopic, name, oeuvre, cac, macromolecule, technologists, buyer, sensing,
# Nearest to square: mile, tate, serendipity, wall, kali, laszlo, ntr, affonso,
# Nearest to operating: unix, boarded, fp, vetted, paveway, hubs, virtual, microsoft,
# Nearest to question: petherbridge, arminians, passively, affirms, itil, subservient, colds, asks,
# Nearest to universe: excitatory, bang, brane, galaxies, quasars, cosmic, herschel, invoking,
# Nearest to cost: worth, spacecrafts, recognising, correctness, penny, objector, reduced, iie,
# Nearest to applied: experts, commonsense, waddingtons, advanced, electronic, classroom, porous, galleries,
# Nearest to engineering: engineers, canberra, bio, doctorate, tukey, smelt, biomedical, research,
# Nearest to joseph: penitent, samuel, acheson, complicit, sternberg, apuleius, ebenezer, wolpert,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0148 0.1947 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9950 0.1930 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9549 0.1927 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0245 0.1927 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0445 0.1923 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9601 0.1924 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9943 0.1933 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9612 0.1933 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9821 0.1938 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0033 0.1919 sec/batch
# Nearest to to: in, aimed, a, otherwise, question, quaestors, absolute, queueing,
# Nearest to one: four, nine, five, six, three, eight, zero, two,
# Nearest to most: francoist, genres, biola, minority, numerous, tat, staged, studied,
# Nearest to more: assistive, fabricate, greater, pleasing, considerably, metal, photon, rhythm,
# Nearest to called: profess, alveoli, dehydrogenase, persona, flattening, simple, superclasses, traitors,
# Nearest to history: voyaging, external, hatha, cpes, cnet, blish, world, veiled,
# Nearest to been: star, have, discovered, biathletes, developments, admetus, settings, planetoid,
# Nearest to as: oeuvre, microscopic, name, technologists, yaoi, atb, sensing, buyer,
# Nearest to square: mile, tate, serendipity, kali, laszlo, ebenezer, wall, product,
# Nearest to operating: boarded, unix, fp, vetted, hubs, paveway, transceiver, powermac,
# Nearest to question: petherbridge, to, arminians, itil, affirms, passively, subservient, colds,
# Nearest to universe: bang, excitatory, brane, galaxies, quasars, cosmic, herschel, baryonic,
# Nearest to cost: worth, spacecrafts, correctness, recognising, objector, iie, penny, potentially,
# Nearest to applied: experts, commonsense, waddingtons, advanced, forefront, classroom, porous, electronic,
# Nearest to engineering: engineers, canberra, bio, doctorate, tukey, biomedical, rtp, smelt,
# Nearest to joseph: penitent, samuel, acheson, sternberg, complicit, ebenezer, michel, broughton,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9977 0.1943 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9897 0.1928 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9767 0.1929 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0071 0.1926 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0491 0.1932 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0142 0.1932 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9903 0.1926 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9712 0.1926 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9681 0.1924 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0072 0.1940 sec/batch
# Nearest to to: in, aimed, a, otherwise, prominence, is, queueing, golconda,
# Nearest to one: four, nine, five, six, three, eight, two, zero,
# Nearest to most: francoist, numerous, genres, minority, numerals, biola, popular, tat,
# Nearest to more: assistive, fabricate, pleasing, greater, metal, considerably, rhythm, ciders,
# Nearest to called: profess, alveoli, simple, dehydrogenase, traitors, flattening, the, in,
# Nearest to history: world, afridi, histories, veiled, hatha, voyaging, cpes, external,
# Nearest to been: have, star, developments, biathletes, discovered, considers, settings, admetus,
# Nearest to as: oeuvre, name, rowley, macromolecule, microscopic, levantine, buyer, industry,
# Nearest to square: mile, tate, serendipity, kali, laszlo, ntr, ebenezer, affonso,
# Nearest to operating: boarded, unix, fp, vetted, microsoft, virtual, hubs, marginalization,
# Nearest to question: petherbridge, itil, arminians, affirms, colds, subservient, passively, asks,
# Nearest to universe: bang, excitatory, brane, galaxies, quasars, herschel, cosmic, halo,
# Nearest to cost: worth, spacecrafts, recognising, correctness, potentially, reduced, objector, iie,
# Nearest to applied: experts, waddingtons, commonsense, porous, forefront, advanced, famously, electronic,
# Nearest to engineering: engineers, canberra, bio, rtp, doctorate, tukey, biomedical, smelt,
# Nearest to joseph: penitent, samuel, acheson, wolpert, sternberg, solution, michel, complicit,
# ...
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7697 0.1940 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8308 0.1940 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8644 0.1931 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8566 0.1930 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8580 0.1935 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8480 0.1942 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9117 0.1944 sec/batch
# Nearest to to: in, a, and, with, their, the, of, is,
# Nearest to one: four, nine, five, six, three, two, eight, zero,
# Nearest to most: which, for, in, the, of, other, often, many,
# Nearest to more: considerably, than, greater, assistive, most, to, longer, these,
# Nearest to called: the, in, for, a, simple, an, other, of,
# Nearest to history: histories, cnet, culture, external, world, modern, cpes, afridi,
# Nearest to been: have, has, are, discovered, found, for, had, were,
# Nearest to as: and, to, for, by, of, the, such, in,
# Nearest to square: tate, mile, kali, vertex, wall, huge, endorsing, thoroughfares,
# Nearest to operating: boarded, marginalization, unix, tried, hubs, jazz, onboard, vetted,
# Nearest to question: petherbridge, questions, answer, if, rebooted, keyboardist, asks, itil,
# Nearest to universe: brane, bang, quasars, excitatory, ultimate, cosmogony, cosmic, everett,
# Nearest to cost: worth, potentially, spacecrafts, mcluhan, reduced, dollars, recognising, facilities,
# Nearest to applied: experts, waddingtons, orkney, classroom, porous, steadfast, advanced, commonsense,
# Nearest to engineering: engineers, mechanical, canberra, iit, wheeler, smelt, hodge, daisuke,
# Nearest to joseph: penitent, samuel, acheson, latter, brigham, beaconsfield, immigrate, nitroglycerin,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8005 0.1953 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8780 0.1936 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8629 0.1929 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8448 0.1931 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8588 0.1936 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8583 0.1946 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8436 0.1932 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8543 0.1944 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8898 0.1936 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8937 0.1937 sec/batch
# Nearest to to: in, a, and, their, with, the, of, as,
# Nearest to one: four, nine, five, six, three, two, eight, zero,
# Nearest to most: for, which, the, in, of, were, numerous, other,
# Nearest to more: considerably, than, greater, assistive, longer, some, philanthropy, sundanese,
# Nearest to called: in, the, for, a, simple, other, an, of,
# Nearest to history: histories, culture, external, world, modern, cnet, miramax, licht,
# Nearest to been: have, has, discovered, had, for, are, were, found,
# Nearest to as: the, by, and, for, of, to, a, an,
# Nearest to square: tate, mile, kali, vertex, endorsing, serendipity, huge, thoroughfares,
# Nearest to operating: boarded, marginalization, unix, jazz, hubs, tried, onboard, vetted,
# Nearest to question: petherbridge, questions, answer, keyboardist, asks, rebooted, if, itil,
# Nearest to universe: brane, quasars, ultimate, bang, cosmic, cosmogony, excitatory, everett,
# Nearest to cost: worth, potentially, spacecrafts, mcluhan, dollars, recognising, reduced, facilities,
# Nearest to applied: experts, waddingtons, porous, advanced, goodhue, rafter, orkney, commonsense,
# Nearest to engineering: engineers, mechanical, canberra, wheeler, iit, smelt, hodge, toner,
# Nearest to joseph: penitent, samuel, acheson, latter, michel, immigrate, brigham, nitroglycerin,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8563 0.1947 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8358 0.1931 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8380 0.1941 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8249 0.1936 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9099 0.1950 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8321 0.1949 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9761 0.1938 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8799 0.1933 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9229 0.1935 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8291 0.1938 sec/batch
# Nearest to to: in, a, and, the, with, their, as, of,
# Nearest to one: four, nine, five, six, two, three, eight, zero,
# Nearest to most: which, for, the, has, considered, numerous, francoist, mostly,
# Nearest to more: than, considerably, greater, assistive, longer, are, to, sundanese,
# Nearest to called: for, the, in, a, an, simple, pianists, lamiales,
# Nearest to history: histories, world, external, culture, modern, cnet, afridi, miramax,
# Nearest to been: have, has, are, had, found, discovered, it, for,
# Nearest to as: and, by, for, the, a, of, to, an,
# Nearest to square: tate, mile, kali, vertex, thoroughfares, endorsing, huge, wall,
# Nearest to operating: boarded, marginalization, unix, jazz, onboard, vetted, hubs, populace,
# Nearest to question: petherbridge, questions, answer, if, asks, keyboardist, arminians, rebooted,
# Nearest to universe: brane, ultimate, quasars, excitatory, cosmic, cosmogony, everett, bang,
# Nearest to cost: worth, potentially, spacecrafts, mcluhan, dollars, recognising, reduced, objector,
# Nearest to applied: experts, porous, waddingtons, rafter, advanced, universit, jak, embody,
# Nearest to engineering: engineers, mechanical, canberra, iit, hodge, daisuke, wheeler, smelt,
# Nearest to joseph: penitent, samuel, acheson, latter, ossetia, immigrate, brigham, beaconsfield,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8072 0.1946 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8779 0.1935 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8013 0.1935 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8509 0.1932 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8700 0.1931 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8880 0.1933 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8768 0.1279 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8469 0.1940 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8240 0.1934 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8592 0.1934 sec/batch
# Nearest to to: a, in, and, the, with, their, of, as,
# Nearest to one: four, nine, five, six, two, eight, three, seven,
# Nearest to most: which, for, considered, has, in, are, many, as,
# Nearest to more: than, considerably, are, greater, assistive, longer, most, to,
# Nearest to called: the, a, for, in, an, simple, of, lamiales,
# Nearest to history: histories, external, world, cnet, modern, culture, afridi, veiled,
# Nearest to been: have, discovered, had, has, are, it, were, found,
# Nearest to as: and, for, to, by, of, a, in, an,
# Nearest to square: tate, mile, kali, vertex, wall, serendipity, thoroughfares, endorsing,
# Nearest to operating: marginalization, boarded, unix, jazz, populace, pharmaceutical, hubs, frontispiece,
# Nearest to question: petherbridge, questions, answer, if, arminians, keyboardist, rebooted, asks,
# Nearest to universe: brane, ultimate, excitatory, quasars, everett, cosmic, cosmogony, bang,
# Nearest to cost: worth, potentially, spacecrafts, dollars, mcluhan, recognising, reduced, prices,
# Nearest to applied: experts, waddingtons, porous, advanced, rafter, universit, steadfast, jak,
# Nearest to engineering: engineers, mechanical, wheeler, iit, canberra, chemistry, smelt, toner,
# Nearest to joseph: penitent, samuel, acheson, latter, michel, beaconsfield, ossetia, brigham,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8157 0.1949 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8004 0.1937 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7989 0.1935 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8486 0.1928 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8642 0.1948 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8093 0.1929 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8764 0.2180 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7220 0.1929 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8207 0.1941 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7599 0.1930 sec/batch
# Nearest to to: a, in, the, and, with, is, as, for,
# Nearest to one: four, nine, five, six, two, three, zero, eight,
# Nearest to most: which, for, in, the, of, as, are, other,
# Nearest to more: than, considerably, are, some, to, these, greater, most,
# Nearest to called: the, in, for, a, an, is, of, simple,
# Nearest to history: histories, world, external, modern, culture, cnet, of, armenia,
# Nearest to been: have, has, are, discovered, found, it, for, had,
# Nearest to as: and, to, the, for, in, such, a, by,
# Nearest to square: tate, mile, vertex, kali, wall, thoroughfares, endorsing, serendipity,
# Nearest to operating: marginalization, boarded, unix, jazz, populace, hubs, pharmaceutical, dendrites,
# Nearest to question: petherbridge, questions, answer, if, keyboardist, rebooted, arminians, asks,
# Nearest to universe: brane, cosmic, excitatory, quasars, bang, ultimate, cosmogony, abundances,
# Nearest to cost: worth, potentially, spacecrafts, mcluhan, dollars, recognising, restraining, objector,
# Nearest to applied: experts, advanced, waddingtons, porous, orkney, mohel, steadfast, goodhue,
# Nearest to engineering: engineers, mechanical, iit, aldershot, wheeler, chemistry, canberra, hodge,
# Nearest to joseph: penitent, latter, acheson, samuel, ossetia, immigrate, beaconsfield, michel,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7858 0.1953 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8321 0.1932 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8580 0.1932 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8096 0.1932 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8277 0.1930 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8950 0.1931 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.7986 0.1933 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8164 0.1930 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8426 0.1930 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8538 0.1932 sec/batch
# Nearest to to: in, a, and, the, their, with, is, of,
# Nearest to one: four, nine, five, six, three, two, eight, zero,
# Nearest to most: which, for, in, the, other, many, are, as,
# Nearest to more: considerably, than, most, greater, to, some, assistive, these,
# Nearest to called: in, the, for, a, is, an, other, of,
# Nearest to history: histories, external, modern, world, cnet, culture, licht, see,
# Nearest to been: have, has, are, discovered, found, had, that, recent,
# Nearest to as: by, the, and, in, of, a, an, to,
# Nearest to square: tate, mile, kali, vertex, wall, thoroughfares, product, endorsing,
# Nearest to operating: marginalization, boarded, unix, jazz, populace, hubs, tried, frontispiece,
# Nearest to question: questions, petherbridge, answer, keyboardist, if, rebooted, asks, arminians,
# Nearest to universe: brane, cosmic, bang, quasars, excitatory, ultimate, everett, abundances,
# Nearest to cost: worth, potentially, mcluhan, spacecrafts, dollars, cough, recognising, plummeted,
# Nearest to applied: experts, waddingtons, porous, mohel, advanced, rafter, steadfast, commonsense,
# Nearest to engineering: engineers, mechanical, iit, aldershot, wheeler, canberra, chemistry, toner,
# Nearest to joseph: penitent, acheson, latter, samuel, immigrate, ossetia, tert, michel,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8158 0.1947 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8660 0.1933 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8438 0.1937 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8188 0.1936 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8674 0.1933 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8456 0.1936 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8461 0.1932 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8598 0.1937 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8025 0.1944 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8105 0.1929 sec/batch
# Nearest to to: in, a, the, and, with, for, as, not,
# Nearest to one: nine, four, five, two, six, three, eight, zero,
# Nearest to most: which, for, the, in, as, other, of, were,
# Nearest to more: than, considerably, are, greater, most, these, to, some,
# Nearest to called: in, the, for, a, an, is, other, with,
# Nearest to history: histories, culture, external, world, of, modern, see, mintz,
# Nearest to been: have, has, are, had, that, were, found, discovered,
# Nearest to as: and, the, by, in, of, to, for, a,
# Nearest to square: tate, mile, kali, huge, vertex, thoroughfares, wall, endorsing,
# Nearest to operating: marginalization, boarded, unix, jazz, hubs, cp, tried, populace,
# Nearest to question: petherbridge, questions, answer, keyboardist, if, asks, itil, rebooted,
# Nearest to universe: brane, cosmic, quasars, bang, ultimate, abundances, excitatory, everett,
# Nearest to cost: worth, potentially, dollars, mcluhan, cough, spacecrafts, recognising, restraining,
# Nearest to applied: experts, waddingtons, mohel, orkney, steadfast, rafter, advanced, porous,
# Nearest to engineering: engineers, mechanical, iit, aldershot, wheeler, canberra, daisuke, smelt,
# Nearest to joseph: penitent, acheson, latter, samuel, tert, michel, ossetia, caress,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8578 0.1949 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8240 0.1948 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9304 0.1958 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8957 0.1948 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8942 0.1931 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8182 0.1933 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7819 0.1932 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8396 0.1931 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7438 0.1936 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8234 0.1938 sec/batch
# Nearest to to: a, in, with, and, for, the, as, not,
# Nearest to one: nine, four, five, six, eight, three, two, seven,
# Nearest to most: which, for, as, many, other, in, were, has,
# Nearest to more: than, considerably, to, greater, are, these, most, as,
# Nearest to called: in, for, the, a, an, is, identical, simple,
# Nearest to history: histories, culture, of, external, see, world, modern, cnet,
# Nearest to been: have, has, are, had, found, recent, it, similar,
# Nearest to as: and, for, by, a, the, in, to, of,
# Nearest to square: tate, mile, kali, vertex, huge, wall, thoroughfares, endorsing,
# Nearest to operating: marginalization, boarded, unix, jazz, hubs, populace, dendrites, cp,
# Nearest to question: questions, answer, petherbridge, keyboardist, if, greenwald, rebooted, wasn,
# Nearest to universe: brane, cosmic, quasars, bang, ultimate, excitatory, abundances, hyperfine,
# Nearest to cost: worth, potentially, dollars, mcluhan, spacecrafts, recognising, cough, objector,
# Nearest to applied: experts, waddingtons, advanced, porous, orkney, used, mohel, universit,
# Nearest to engineering: engineers, mechanical, iit, aldershot, daisuke, wheeler, chemistry, smelt,
# Nearest to joseph: penitent, acheson, latter, samuel, tert, dcccd, caress, jug,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8371 0.1951 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8201 0.1937 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
